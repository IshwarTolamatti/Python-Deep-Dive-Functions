# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Dump\\Ishwar\\Data_Science\\Edureka\\Class 3\\Dataset\\bank-data.csv")

# %%
df
# Out:
#      age            job   marital    y
# 0     20        student    single  yes
# 1     32     management    single  yes
# 2     49     technician   married  yes
# 3     32    blue-collar   married  yes
# 4     33     management   married  yes
# 5     61         admin.   married  yes
# 6     45    blue-collar  divorced  yes
# 7     34     technician   married  yes
# 8     37     management   married  yes
# 9     27         admin.  divorced  yes
# 10    52       services   married  yes
# 11    37     management   married  yes
# 12    27       services    single  yes
# 13    21        student    single  yes
# 14    25        student    single  yes
# 15    25     technician    single  yes
# 16    34  self-employed    single  yes
# 17    52     management   married  yes
# 18    55         admin.   married  yes
# 19    28     management    single  yes
# 20    35     technician    single  yes
# 21    29    blue-collar    single  yes
# 22    42     management   married  yes
# ...

# %%
a=df["job"].unique()
a
# Out:
# array(['student', 'management', 'technician', 'blue-collar', 'admin.',
#        'services', 'self-employed', 'entrepreneur', 'housemaid'],
#       dtype=object)

# %%
set1=set(a)
set1
# Out:
# {'admin.',
#  'blue-collar',
#  'entrepreneur',
#  'housemaid',
#  'management',
#  'self-employed',
#  'services',
#  'student',
#  'technician'}

# %%
lst1=list(a)
lst1
# Out:
# ['student',
#  'management',
#  'technician',
#  'blue-collar',
#  'admin.',
#  'services',
#  'self-employed',
#  'entrepreneur',
#  'housemaid']

# %%
profession=input("Please enter your profession:")
if profession in str(lst1):
    print(profession + " is there in the list")
else:
    print(profession + " not there in profession list")
# Out:
# Please enter your profession:'services'
# 'services' is there in the list
